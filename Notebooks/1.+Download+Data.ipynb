# %% [markdown]
# # 1. Download Dogs vs Cats dataset

# %% [markdown]
# You can grab the dataset needed from Kaggle. There two competitions with similar name but we will be working with https://www.kaggle.com/c/dogs-vs-cats not the one suffixed with Redux. Anyway all you need is a free Kaggle account to download data and you can use your gmail or facebook account as I recall. To simplify things and to make this tutorial self-contained I have downloaded the files and hosted them publicly on Azure.
#
# The next step will be to download the files and extract them in a data folder locally

# %%
# ! wget https://yousrysa.blob.core.windows.net/dogs-vs-cats/train.zip

! wget https://yousrysa.blob.core.windows.net/dogs-vs-cats/dogs-vs-cats.zip
# Out:
# --2017-09-09 12:23:35--  https://yousrysa.blob.core.windows.net/dogs-vs-cats/dogs-vs-cats.zip
# Resolving yousrysa.blob.core.windows.net (yousrysa.blob.core.windows.net)... 52.239.158.132
# Connecting to yousrysa.blob.core.windows.net (yousrysa.blob.core.windows.net)|52.239.158.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 126012568 (120M) [application/zip]
# Saving to: ‘dogs-vs-cats.zip’
#
# dogs-vs-cats.zip    100%[===================>] 120.17M  26.2MB/s    in 5.0s
#
# 2017-09-09 12:23:41 (24.1 MB/s) - ‘dogs-vs-cats.zip’ saved [126012568/126012568]

# %% [markdown]
# Let's unzip those files in a folder called data

# %%
! unzip dogs-vs-cats -d data/
# Out:
# Archive:  dogs-vs-cats.zip
#    creating: data/test/
#    creating: data/test/cats/
#   inflating: data/test/cats/cat.10.jpg
#   inflating: data/test/cats/cat.10010.jpg
#   inflating: data/test/cats/cat.10018.jpg
#   inflating: data/test/cats/cat.10021.jpg
#   inflating: data/test/cats/cat.10026.jpg
#   inflating: data/test/cats/cat.10030.jpg
#   inflating: data/test/cats/cat.1004.jpg
#   inflating: data/test/cats/cat.10043.jpg
#   inflating: data/test/cats/cat.1005.jpg
#   inflating: data/test/cats/cat.10058.jpg
#   inflating: data/test/cats/cat.10060.jpg
#   inflating: data/test/cats/cat.10064.jpg
#   inflating: data/test/cats/cat.10070.jpg
#   inflating: data/test/cats/cat.10084.jpg
#   inflating: data/test/cats/cat.10090.jpg
#   inflating: data/test/cats/cat.10101.jpg
#   inflating: data/test/cats/cat.10116.jpg
#   inflating: data/test/cats/cat.1012.jpg
#   inflating: data/test/cats/cat.10120.jpg
#   inflating: data/test/cats/cat.10132.jpg
# ...

# %%
! ls data/
! ls data/train
# Out:
# test  train
# cats  dogs

# %%
! ls data/test/dogs
# Out:
# dog.4490.jpg  dog.4629.jpg  dog.4713.jpg  dog.4817.jpg	dog.4905.jpg
# dog.4492.jpg  dog.4631.jpg  dog.4717.jpg  dog.4820.jpg	dog.4907.jpg
# dog.4496.jpg  dog.4633.jpg  dog.4719.jpg  dog.4821.jpg	dog.4911.jpg
# dog.4497.jpg  dog.463.jpg   dog.471.jpg   dog.4826.jpg	dog.4916.jpg
# dog.450.jpg   dog.4642.jpg  dog.4723.jpg  dog.4829.jpg	dog.4918.jpg
# dog.451.jpg   dog.4647.jpg  dog.4727.jpg  dog.4831.jpg	dog.491.jpg
# dog.4559.jpg  dog.4653.jpg  dog.4728.jpg  dog.4833.jpg	dog.4923.jpg
# dog.4562.jpg  dog.4656.jpg  dog.4729.jpg  dog.4835.jpg	dog.4925.jpg
# dog.4563.jpg  dog.4657.jpg  dog.4735.jpg  dog.4841.jpg	dog.4930.jpg
# dog.4567.jpg  dog.4664.jpg  dog.4737.jpg  dog.4844.jpg	dog.4935.jpg
# dog.4568.jpg  dog.4668.jpg  dog.4742.jpg  dog.4846.jpg	dog.4936.jpg
# dog.456.jpg   dog.4672.jpg  dog.4744.jpg  dog.4849.jpg	dog.4937.jpg
# dog.4570.jpg  dog.4673.jpg  dog.4747.jpg  dog.484.jpg	dog.4940.jpg
# dog.4571.jpg  dog.4675.jpg  dog.4748.jpg  dog.4852.jpg	dog.4942.jpg
# ...
